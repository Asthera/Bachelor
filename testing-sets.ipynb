# %%
import matplotlib.pyplot as plt
import cv2

# %%
# show image
path = "/Volumes/LaCie/Macbook/cropped/video_frames/001_image_211589708848.mp4/frame_19.png"

# %%
# read image as grayscale
img = cv2.imread(path)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gray, cmap='gray')
plt.show()
