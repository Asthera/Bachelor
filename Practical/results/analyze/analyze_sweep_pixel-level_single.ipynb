# %%
from read_sweep import SweepReader
from edit_sweep_df import SweepEditorDataFrame

# %%
# affine_single name of the sweep
sweep_id = "cruht9ii"
project_path = "daswoldemar/bachelor"

# %%
# read sweep, save raw
reader = SweepReader(sweep_id, project_path)
df_raw = reader.fetch_sweep_runs()
reader.save_to_csv("sweeps_raw/"+sweep_id+".csv")
# Out:
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# wandb:   1 of 1 files downloaded.
# Data saved to CSV file

# %%
# edit sweep, save edited
editor = SweepEditorDataFrame([df_raw,])
df_edited = editor.init_edit()
df_edited.to_csv("sweeps_edited/"+sweep_id+".csv")

# %%
df_edited
# Out:
#                                                     Test F1_mean  Test F1_max  \
# Transforms
# CT.RandomBrightnessByAdd(p=0.5, delta=(-0.15, 0...      0.215564     0.588235
# CT.RandomBrightnessByAdd(p=0.5, delta=(-0.25, 0...      0.231989     0.794872
# CT.RandomBrightnessByAdd(p=0.5, delta=(-0.35, 0...      0.333553     0.777778
# CT.RandomBrightnessByAdd(p=0.5, delta=(0.05, 0....      0.264183     0.538462
# CT.RandomBrightnessByAdd(p=0.5, delta=(0.15, 0....      0.177327     0.421053
# ...                                                          ...          ...
# T.RandomApply([T.GaussianBlur(kernel_size=3, si...      0.253364     0.636364
# T.RandomApply([T.GaussianBlur(kernel_size=5, si...      0.269272     0.853659
# T.RandomApply([T.GaussianBlur(kernel_size=5, si...      0.132826     0.419355
# T.RandomApply([T.GaussianBlur(kernel_size=5, si...      0.259813     0.853659
# T.RandomApply([T.GaussianBlur(kernel_size=5, si...      0.097065     0.351351
#
#                                                     Test F1_min  \
# Transforms
# CT.RandomBrightnessByAdd(p=0.5, delta=(-0.15, 0...          0.0
# CT.RandomBrightnessByAdd(p=0.5, delta=(-0.25, 0...          0.0
# CT.RandomBrightnessByAdd(p=0.5, delta=(-0.35, 0...          0.0
# CT.RandomBrightnessByAdd(p=0.5, delta=(0.05, 0....          0.0
# CT.RandomBrightnessByAdd(p=0.5, delta=(0.15, 0....          0.0
# ...                                                         ...
# T.RandomApply([T.GaussianBlur(kernel_size=3, si...          0.0
# T.RandomApply([T.GaussianBlur(kernel_size=5, si...          0.0
# T.RandomApply([T.GaussianBlur(kernel_size=5, si...          0.0
# T.RandomApply([T.GaussianBlur(kernel_size=5, si...          0.0
# T.RandomApply([T.GaussianBlur(kernel_size=5, si...          0.0
#
#                                                     Test Precision_mean  \
# Transforms
# CT.RandomBrightnessByAdd(p=0.5, delta=(-0.15, 0...             0.250272
# CT.RandomBrightnessByAdd(p=0.5, delta=(-0.25, 0...             0.261442
# CT.RandomBrightnessByAdd(p=0.5, delta=(-0.35, 0...             0.554446
# CT.RandomBrightnessByAdd(p=0.5, delta=(0.05, 0....             0.419690
# CT.RandomBrightnessByAdd(p=0.5, delta=(0.15, 0....             0.360313
# ...                                                                 ...
# T.RandomApply([T.GaussianBlur(kernel_size=3, si...             0.429199
# T.RandomApply([T.GaussianBlur(kernel_size=5, si...             0.606316
# T.RandomApply([T.GaussianBlur(kernel_size=5, si...             0.301904
# T.RandomApply([T.GaussianBlur(kernel_size=5, si...             0.445552
# T.RandomApply([T.GaussianBlur(kernel_size=5, si...             0.282456
#
#                                                     Test Precision_max  \
# Transforms
# CT.RandomBrightnessByAdd(p=0.5, delta=(-0.15, 0...            0.733333
# CT.RandomBrightnessByAdd(p=0.5, delta=(-0.25, 0...            1.000000
# CT.RandomBrightnessByAdd(p=0.5, delta=(-0.35, 0...            1.000000
# CT.RandomBrightnessByAdd(p=0.5, delta=(0.05, 0....            1.000000
# CT.RandomBrightnessByAdd(p=0.5, delta=(0.15, 0....            1.000000
# ...                                                                ...
# T.RandomApply([T.GaussianBlur(kernel_size=3, si...            1.000000
# T.RandomApply([T.GaussianBlur(kernel_size=5, si...            1.000000
# T.RandomApply([T.GaussianBlur(kernel_size=5, si...            1.000000
# T.RandomApply([T.GaussianBlur(kernel_size=5, si...            1.000000
# T.RandomApply([T.GaussianBlur(kernel_size=5, si...            1.000000
#
#                                                     Test Precision_min  \
# Transforms
# CT.RandomBrightnessByAdd(p=0.5, delta=(-0.15, 0...                 0.0
# CT.RandomBrightnessByAdd(p=0.5, delta=(-0.25, 0...                 0.0
# CT.RandomBrightnessByAdd(p=0.5, delta=(-0.35, 0...                 0.0
# CT.RandomBrightnessByAdd(p=0.5, delta=(0.05, 0....                 0.0
# CT.RandomBrightnessByAdd(p=0.5, delta=(0.15, 0....                 0.0
# ...                                                                ...
# T.RandomApply([T.GaussianBlur(kernel_size=3, si...                 0.0
# T.RandomApply([T.GaussianBlur(kernel_size=5, si...                 0.0
# T.RandomApply([T.GaussianBlur(kernel_size=5, si...                 0.0
# T.RandomApply([T.GaussianBlur(kernel_size=5, si...                 0.0
# T.RandomApply([T.GaussianBlur(kernel_size=5, si...                 0.0
#
#                                                     Test Recall_mean  \
# Transforms
# CT.RandomBrightnessByAdd(p=0.5, delta=(-0.15, 0...          0.234016
# CT.RandomBrightnessByAdd(p=0.5, delta=(-0.25, 0...          0.228423
# CT.RandomBrightnessByAdd(p=0.5, delta=(-0.35, 0...          0.282481
# CT.RandomBrightnessByAdd(p=0.5, delta=(0.05, 0....          0.271053
# CT.RandomBrightnessByAdd(p=0.5, delta=(0.15, 0....          0.247137
# ...                                                              ...
# T.RandomApply([T.GaussianBlur(kernel_size=3, si...          0.250523
# T.RandomApply([T.GaussianBlur(kernel_size=5, si...          0.224280
# T.RandomApply([T.GaussianBlur(kernel_size=5, si...          0.118730
# T.RandomApply([T.GaussianBlur(kernel_size=5, si...          0.260259
# T.RandomApply([T.GaussianBlur(kernel_size=5, si...          0.100763
#
#                                                     Test Recall_max  \
# Transforms
# CT.RandomBrightnessByAdd(p=0.5, delta=(-0.15, 0...         0.744681
# CT.RandomBrightnessByAdd(p=0.5, delta=(-0.25, 0...         0.659574
# CT.RandomBrightnessByAdd(p=0.5, delta=(-0.35, 0...         0.744681
# CT.RandomBrightnessByAdd(p=0.5, delta=(0.05, 0....         0.744681
# CT.RandomBrightnessByAdd(p=0.5, delta=(0.15, 0....         0.744681
# ...                                                             ...
# T.RandomApply([T.GaussianBlur(kernel_size=3, si...         0.744681
# T.RandomApply([T.GaussianBlur(kernel_size=5, si...         0.744681
# T.RandomApply([T.GaussianBlur(kernel_size=5, si...         0.371429
# T.RandomApply([T.GaussianBlur(kernel_size=5, si...         0.744681
# T.RandomApply([T.GaussianBlur(kernel_size=5, si...         0.371429
#
#                                                     Test Recall_min  \
# Transforms
# CT.RandomBrightnessByAdd(p=0.5, delta=(-0.15, 0...              0.0
# CT.RandomBrightnessByAdd(p=0.5, delta=(-0.25, 0...              0.0
# CT.RandomBrightnessByAdd(p=0.5, delta=(-0.35, 0...              0.0
# CT.RandomBrightnessByAdd(p=0.5, delta=(0.05, 0....              0.0
# CT.RandomBrightnessByAdd(p=0.5, delta=(0.15, 0....              0.0
# ...                                                             ...
# T.RandomApply([T.GaussianBlur(kernel_size=3, si...              0.0
# T.RandomApply([T.GaussianBlur(kernel_size=5, si...              0.0
# T.RandomApply([T.GaussianBlur(kernel_size=5, si...              0.0
# T.RandomApply([T.GaussianBlur(kernel_size=5, si...              0.0
# T.RandomApply([T.GaussianBlur(kernel_size=5, si...              0.0
#
#                                                    Test Accuracy_mean  \
# Transforms
# CT.RandomBrightnessByAdd(p=0.5, delta=(-0.15, 0...                NaN
# CT.RandomBrightnessByAdd(p=0.5, delta=(-0.25, 0...                NaN
# CT.RandomBrightnessByAdd(p=0.5, delta=(-0.35, 0...                NaN
# CT.RandomBrightnessByAdd(p=0.5, delta=(0.05, 0....                NaN
# CT.RandomBrightnessByAdd(p=0.5, delta=(0.15, 0....                NaN
# ...                                                               ...
# T.RandomApply([T.GaussianBlur(kernel_size=3, si...                NaN
# T.RandomApply([T.GaussianBlur(kernel_size=5, si...                NaN
# T.RandomApply([T.GaussianBlur(kernel_size=5, si...                NaN
# T.RandomApply([T.GaussianBlur(kernel_size=5, si...                NaN
# T.RandomApply([T.GaussianBlur(kernel_size=5, si...                NaN
#
#                                                    Test Accuracy_max  \
# Transforms
# CT.RandomBrightnessByAdd(p=0.5, delta=(-0.15, 0...               NaN
# CT.RandomBrightnessByAdd(p=0.5, delta=(-0.25, 0...               NaN
# CT.RandomBrightnessByAdd(p=0.5, delta=(-0.35, 0...               NaN
# CT.RandomBrightnessByAdd(p=0.5, delta=(0.05, 0....               NaN
# CT.RandomBrightnessByAdd(p=0.5, delta=(0.15, 0....               NaN
# ...                                                              ...
# T.RandomApply([T.GaussianBlur(kernel_size=3, si...               NaN
# T.RandomApply([T.GaussianBlur(kernel_size=5, si...               NaN
# T.RandomApply([T.GaussianBlur(kernel_size=5, si...               NaN
# T.RandomApply([T.GaussianBlur(kernel_size=5, si...               NaN
# T.RandomApply([T.GaussianBlur(kernel_size=5, si...               NaN
#
#                                                    Test Accuracy_min
# Transforms
# CT.RandomBrightnessByAdd(p=0.5, delta=(-0.15, 0...               NaN
# CT.RandomBrightnessByAdd(p=0.5, delta=(-0.25, 0...               NaN
# CT.RandomBrightnessByAdd(p=0.5, delta=(-0.35, 0...               NaN
# CT.RandomBrightnessByAdd(p=0.5, delta=(0.05, 0....               NaN
# CT.RandomBrightnessByAdd(p=0.5, delta=(0.15, 0....               NaN
# ...                                                              ...
# T.RandomApply([T.GaussianBlur(kernel_size=3, si...               NaN
# T.RandomApply([T.GaussianBlur(kernel_size=5, si...               NaN
# T.RandomApply([T.GaussianBlur(kernel_size=5, si...               NaN
# T.RandomApply([T.GaussianBlur(kernel_size=5, si...               NaN
# T.RandomApply([T.GaussianBlur(kernel_size=5, si...               NaN
#
# [76 rows x 12 columns]
